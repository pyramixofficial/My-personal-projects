# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Defining a function that measures the score of the dataset
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn import metrics

# Function for comparing different approaches
def score_dataset(X, y):
    X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.25, random_state = 1)
    model = RandomForestClassifier(n_estimators=100, random_state=24)
    model.fit(X_train, y_train)
    preds = model.predict(X_valid)
    cnf_matrix = metrics.confusion_matrix(y_valid, preds)
    #Plotting the confusion matrix
    class_names=[0,1] # name  of classes
    fig, ax = plt.subplots()
    tick_marks = np.arange(len(class_names))
    plt.xticks(tick_marks, class_names)
    plt.yticks(tick_marks, class_names)

    # create heatmap
    sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
    ax.xaxis.set_label_position("top")
    plt.tight_layout()
    plt.title('Confusion matrix', y=1.1)
    plt.ylabel('Actual label')
    plt.xlabel('Predicted label')
    return accuracy_score(y_valid, preds)

# %%
data = pd.read_csv("Pokemon.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data["Type 2"].value_counts()
# Out:
# Flying      97
# Ground      35
# Poison      34
# Psychic     33
# Fighting    26
# Grass       25
# Fairy       23
# Steel       22
# Dark        20
# Dragon      18
# Water       14
# Ghost       14
# Ice         14
# Rock        14
# Fire        12
# Electric     6
# Normal       4
# Bug          3
# Name: Type 2, dtype: int64

# %%
data['Type 2']=data['Type 2'].fillna("Unknown")

# %%
data
# Out:
#        #                   Name   Type 1   Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass   Poison    318  45      49       49
# 1      2                Ivysaur    Grass   Poison    405  60      62       63
# 2      3               Venusaur    Grass   Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass   Poison    625  80     100      123
# 4      4             Charmander     Fire  Unknown    309  39      52       43
# ..   ...                    ...      ...      ...    ...  ..     ...      ...
# 795  719                Diancie     Rock    Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock    Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic    Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic     Dark    680  80     160       60
# 799  721              Volcanion     Fire    Water    600  80     110      120
#
# ...

# %%
data["Type 2"] = data["Type 2"].astype('category')
data["Type 2"] = data["Type 2"].cat.codes
data
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass      13    318  45      49       49
# 1      2                Ivysaur    Grass      13    405  60      62       63
# 2      3               Venusaur    Grass      13    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass      13    625  80     100      123
# 4      4             Charmander     Fire      17    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock       4    600  50     100      150
# 796  719    DiancieMega Diancie     Rock       4    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic       8    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic       1    680  80     160       60
# 799  721              Volcanion     Fire      18    600  80     110      120
#
# ...

# %%
data["Type 1"] = data["Type 1"].astype('category')
data["Type 1"] = data["Type 1"].cat.codes
data
# Out:
#        #                   Name  Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur       9      13    318  45      49       49
# 1      2                Ivysaur       9      13    405  60      62       63
# 2      3               Venusaur       9      13    525  80      82       83
# 3      3  VenusaurMega Venusaur       9      13    625  80     100      123
# 4      4             Charmander       6      17    309  39      52       43
# ..   ...                    ...     ...     ...    ...  ..     ...      ...
# 795  719                Diancie      15       4    600  50     100      150
# 796  719    DiancieMega Diancie      15       4    700  50     160      110
# 797  720    HoopaHoopa Confined      14       8    600  80     110       60
# 798  720     HoopaHoopa Unbound      14       1    680  80     160       60
# 799  721              Volcanion       6      18    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
data = data.drop("Name", axis = 1)
data
# Out:
#        #  Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0      1       9      13    318  45      49       49       65       65     45
# 1      2       9      13    405  60      62       63       80       80     60
# 2      3       9      13    525  80      82       83      100      100     80
# 3      3       9      13    625  80     100      123      122      120     80
# 4      4       6      17    309  39      52       43       60       50     65
# ..   ...     ...     ...    ...  ..     ...      ...      ...      ...    ...
# 795  719      15       4    600  50     100      150      100      150     50
# 796  719      15       4    700  50     160      110      160      110    110
# 797  720      14       8    600  80     110       60      150      130     70
# 798  720      14       1    680  80     160       60      170      130     80
# 799  721       6      18    600  80     110      120      130       90     70
#
#      Generation  Legendary
# ...

# %%
# Let's see how data is distributed for every column
plt.figure(figsize = (20, 15))
plotnumber = 1

for column in data:
    if plotnumber <= 14:
        ax = plt.subplot(3, 5, plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column, fontsize = 15)
        
    plotnumber += 1
    
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20,8))
sns.heatmap(data.corr(), annot = True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
data["Legendary"] = data["Legendary"].astype(int)
data
# Out:
#        #  Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0      1       9      13    318  45      49       49       65       65     45
# 1      2       9      13    405  60      62       63       80       80     60
# 2      3       9      13    525  80      82       83      100      100     80
# 3      3       9      13    625  80     100      123      122      120     80
# 4      4       6      17    309  39      52       43       60       50     65
# ..   ...     ...     ...    ...  ..     ...      ...      ...      ...    ...
# 795  719      15       4    600  50     100      150      100      150     50
# 796  719      15       4    700  50     160      110      160      110    110
# 797  720      14       8    600  80     110       60      150      130     70
# 798  720      14       1    680  80     160       60      170      130     80
# 799  721       6      18    600  80     110      120      130       90     70
#
#      Generation  Legendary
# ...

# %%
X = data.drop("Legendary", axis = 1)
y = data["Legendary"]

# %%
score_dataset(X, y)
# Out:
# 0.955

# %%
from kydavra import PValueSelector
pv_s = PValueSelector()
selected_cols = pv_s.select(data, 'Legendary')
selected_cols
# Out:
# ['#', 'Type 2', 'Total', 'Sp. Atk', 'Generation']

# %%
X = data[selected_cols]
score_dataset(X, y)
# Out:
# 0.955

# %%
pv_s.plot_process()

# %%
from kydavra import GeneticAlgorithmSelector
gen_sel = GeneticAlgorithmSelector()
rnm = RandomForestClassifier()
selected_columns = gen_sel.select(rnm, data, 'Legendary')
selected_columns
# Out:
# ['#', 'Type 1', 'Type 2', 'Total']

# %%
X = data[selected_cols]
score_dataset(X, y)
# Out:
# 0.955

# %%
from kydavra import PearsonCorrelationSelector
pearson = PearsonCorrelationSelector(min_corr = 0.4)
selected_columns = pearson.select(data, 'Legendary')
selected_columns
# Out:
# ['Total', 'Sp. Atk']

# %%
X = data[selected_cols]
score_dataset(X, y)
# Out:
# 0.955

# %%
from kydavra import LDAReducer
lda = LDAReducer()
selected_columns = lda.reduce(data, 'Legendary')
X = selected_columns.drop('Legendary', axis = 1)
score_dataset(X, y)
# Out:
# 0.945

# %%
from kydavra import MixerSelector
from kydavra import ChiSquaredSelector

# %%
intersect_mix = MixerSelector([PValueSelector(), ChiSquaredSelector(), PearsonCorrelationSelector(min_corr=0.4)], strategy='intersection')
selected_columns = intersect_mix.select(data, 'Legendary')
selected_columns
# Out:
# ['Total', 'Sp. Atk']

# %%
plt.subplots(figsize = (20,10))
plt.title('Attack by Type1')
sns.violinplot(x = "Type 1", y = "Attack",data = data)
plt.ylim(0,200)
plt.show()

# %%
plt.subplots(figsize = (20,10))
plt.title('Attack by Type1')
sns.violinplot(x = "Type 1", y = "Defense",data = data)
plt.ylim(0,200)
plt.show()

# %%
plt.subplots(figsize = (15,5))
plt.title('Strongest Genaration')
sns.violinplot(x = "Generation", y = "Total",data = data)
plt.show()

# %%
def plot_data(data):  
    colors = {0:'blue', 1:'red'}
    fig, ax =plt.subplots()
    ax.scatter(data["Total"], data["Sp. Atk"], c = data['Legendary'].map(colors))

# %%
train_df, test_df = train_test_split(data, random_state=42)
from crucio import SMOTE
smote = SMOTE()
balanced_df = smote.balance(data, 'Legendary')
plot_data(balanced_df)

# %%
X = balanced_df.drop('Legendary', axis = 1)
y = balanced_df["Legendary"]
score_dataset(X, y)
# Out:
# 0.9864130434782609

# %%
from crucio import SMOTEENN
smoteenn = SMOTEENN()
balanced_df = smoteenn.balance(data, 'Legendary')
plot_data(balanced_df)
X = balanced_df.drop('Legendary', axis = 1)
y = balanced_df["Legendary"]
score_dataset(X, y)
# Out:
# 0.9944903581267218

# %%
from crucio import ICOTE
icote = ICOTE()
balanced_df = icote.balance(data, 'Legendary')
plot_data(balanced_df)
X = balanced_df.drop('Legendary', axis = 1)
y = balanced_df["Legendary"]
score_dataset(X, y)
# Out:
# 0.9619565217391305

# %%
from crucio import TKRKNN
tkrknn = TKRKNN()
balanced_df = tkrknn.balance(data, 'Legendary')
plot_data(balanced_df)
X = balanced_df.drop('Legendary', axis = 1)
y = balanced_df["Legendary"]
score_dataset(X, y)
# Out:
# 0.9755434782608695
