# %%
import numpy as np
import pandas as pd

# %%
list_data = [np.random.random() for _ in range(200)]
series = pd.Series(list_data)

for element in series:
	print(element)
# Out:
# 0.7624497430368241
# 0.48123051722692844
# 0.6662852722052932
# 0.3793404760385162
# 0.40440246982768113
# 0.6408075689745201
# 0.5517860700304948
# 0.951067647215444
# 0.8941872208097348
# 0.5347449631614261
# 0.3327248420156744
# 0.4873047468475912
# 0.17779794953384465
# 0.4800585534536691
# 0.5059391964041281
# 0.030057377778955452
# 0.8374547528646382
# 0.08130456301568678
# 0.9499117238128777
# 0.5524402099567147
# 0.770839396782777
# 0.28742580806982965
# 0.8474908145765365
# 0.6127614146006131
# 0.06301040046343542
# 0.3843717574768153
# 0.3074289264303519
# 0.8981073024564971
# 0.8548011712837702
# 0.22226639454139197
# 0.45303118431668044
# 0.3042900807321979
# 0.5523991266020376
# 0.4221303358523919
# 0.5213844671886381
# 0.0703781919552755
# 0.10883698867182001
# 0.8018342634803017
# 0.9452468932842583
# 0.49396600170729543
# 0.08907790561711126
# 0.9815111326867779
# 0.039119163570918825
# 0.48963961903313924
# 0.9314437367036977
# 0.6848841213378052
# ...

# %%
#Computing the minimal value of a series
min_value = series.min()
print('\n', 'Minim value: ', min_value)
# Out:
#  Minim value:  0.01820156138399509

# %%
#Computing the maximal value of a series
max_value = series.max()
print('\n', 'Maximum value: ', max_value)
# Out:
#  Maximum value:  0.9959598919517583

# %%
#Computing the mean value of a series
mean = series.mean()
print('\n', 'Mean value: ',mean)
# Out:
#  Mean value:  0.5001350558825841

# %%
#Computing the median value of a series
median = series.median()
print('\n', 'Median value: ', median)
# Out:
#  Median value:  0.49806517562650054

# %%
#Computing the mode value of a series
mode = series.mode()
print('\n', 'Mode value: ', mode)
# Out:
#  Mode value:  0      0.018202
# 1      0.018408
# 2      0.030057
# 3      0.039119
# 4      0.046475
#          ...
# 195    0.979146
# 196    0.981348
# 197    0.981511
# 198    0.982165
# 199    0.995960
# Length: 200, dtype: float64

# %%
#Finding the index of the minimal value of series
min_index = series.argmin()
print('\n', 'Index of minimal value: ', min_index)
# Out:
#  Index of minimal value:  74

# %%
#Finding the index of the maximal value of series
max_index = series.argmax()
print('\n', 'Index of maximal value: ', max_index)
# Out:
#  Index of maximal value:  101

# %%
#Generating a random matrix in numpy
matrix = np.random.random((10, 5))

# %%
#Creating the pandas dataframe
df = pd.DataFrame(matrix)
df
# Out:
#           0         1         2         3         4
# 0  0.418500  0.256708  0.659561  0.848265  0.223592
# 1  0.077223  0.829760  0.422341  0.678942  0.530219
# 2  0.305370  0.303723  0.789972  0.915413  0.913050
# 3  0.481442  0.613523  0.486134  0.884540  0.324800
# 4  0.380794  0.966401  0.070655  0.221355  0.243825
# 5  0.630175  0.056958  0.050730  0.409073  0.787237
# 6  0.315606  0.647417  0.969404  0.903286  0.745493
# 7  0.648452  0.604360  0.224354  0.376333  0.657082
# 8  0.310990  0.756377  0.650157  0.062370  0.343877
# 9  0.280996  0.646138  0.385322  0.768227  0.701150

# %%
#Giving name to the columns
df = pd.DataFrame(matrix, columns = ['col1', 'col2', 'col3', 'col4', 'col5'])
df
# Out:
#        col1      col2      col3      col4      col5
# 0  0.418500  0.256708  0.659561  0.848265  0.223592
# 1  0.077223  0.829760  0.422341  0.678942  0.530219
# 2  0.305370  0.303723  0.789972  0.915413  0.913050
# 3  0.481442  0.613523  0.486134  0.884540  0.324800
# 4  0.380794  0.966401  0.070655  0.221355  0.243825
# 5  0.630175  0.056958  0.050730  0.409073  0.787237
# 6  0.315606  0.647417  0.969404  0.903286  0.745493
# 7  0.648452  0.604360  0.224354  0.376333  0.657082
# 8  0.310990  0.756377  0.650157  0.062370  0.343877
# 9  0.280996  0.646138  0.385322  0.768227  0.701150

# %%
df[['col1', 'col2']]
# Out:
#        col1      col2
# 0  0.418500  0.256708
# 1  0.077223  0.829760
# 2  0.305370  0.303723
# 3  0.481442  0.613523
# 4  0.380794  0.966401
# 5  0.630175  0.056958
# 6  0.315606  0.647417
# 7  0.648452  0.604360
# 8  0.310990  0.756377
# 9  0.280996  0.646138

# %%
#Get a specific value from the table
df.iloc[0, 1]
# Out:
# 0.25670839436048876

# %%
df.iloc[:, 1:]
# Out:
#        col2      col3      col4      col5
# 0  0.256708  0.659561  0.848265  0.223592
# 1  0.829760  0.422341  0.678942  0.530219
# 2  0.303723  0.789972  0.915413  0.913050
# 3  0.613523  0.486134  0.884540  0.324800
# 4  0.966401  0.070655  0.221355  0.243825
# 5  0.056958  0.050730  0.409073  0.787237
# 6  0.647417  0.969404  0.903286  0.745493
# 7  0.604360  0.224354  0.376333  0.657082
# 8  0.756377  0.650157  0.062370  0.343877
# 9  0.646138  0.385322  0.768227  0.701150

# %%
df.values
# Out:
# array([[0.41850018, 0.25670839, 0.65956125, 0.84826475, 0.22359206],
#        [0.07722289, 0.82975995, 0.42234101, 0.67894176, 0.53021883],
#        [0.30537049, 0.30372325, 0.78997163, 0.91541344, 0.91304969],
#        [0.48144182, 0.613523  , 0.48613391, 0.88454034, 0.3247999 ],
#        [0.38079427, 0.96640078, 0.07065451, 0.22135523, 0.24382469],
#        [0.63017523, 0.05695787, 0.05073019, 0.40907301, 0.78723727],
#        [0.31560592, 0.6474165 , 0.96940386, 0.90328593, 0.74549309],
#        [0.64845195, 0.60435997, 0.22435442, 0.37633282, 0.65708173],
#        [0.31099   , 0.75637742, 0.65015726, 0.06237017, 0.34387685],
#        [0.28099559, 0.64613826, 0.38532167, 0.76822713, 0.70115049]])

# %%
df = pd.read_csv('heart.csv')

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# ...

# %%
df.mean()
# Out:
# age          54.366337
# sex           0.683168
# cp            0.966997
# trestbps    131.623762
# chol        246.264026
# fbs           0.148515
# restecg       0.528053
# thalach     149.646865
# exang         0.326733
# oldpeak       1.039604
# slope         1.399340
# ca            0.729373
# thal          2.313531
# target        0.544554
# dtype: float64

# %%
#Get the main statistical parameters for all columns with describe
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
#Finding the correlation between the columns
df.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trestbps  0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalach  -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exang     0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slope    -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# ca        0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thal      0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# ...

# %%
#Finding the frequencies of a categorial colummn using value_counts
df['sex'].value_counts()
# Out:
# 1    207
# 0     96
# Name: sex, dtype: int64

# %%
#Finding the mean value of cholesterol for every gender

#Pythonic way
for key in dict(df['sex'].value_counts()):
    print(f"{key} - {df[df['sex'] == key]['chol'].mean()}")

#Shorter wary
df.groupby(['sex'])['chol'].mean()
# Out:
# 1 - 239.28985507246378
# 0 - 261.3020833333333
# sex
# 0    261.302083
# 1    239.289855
# Name: chol, dtype: float64

# %%
#Replacing numbers with gender names
df['sex'] = df['sex'].map({0: 'female', 1: 'male'})
df['sex']
# Out:
# 0        male
# 1        male
# 2      female
# 3        male
# 4      female
#         ...
# 298    female
# 299      male
# 300      male
# 301      male
# 302    female
# Name: sex, Length: 303, dtype: object

# %%
#Replacing gender names with numbers
df['sex'] = df['sex'].map({'female': 0, 'male': 1})
df['sex']
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 298    0
# 299    1
# 300    1
# 301    1
# 302    0
# Name: sex, Length: 303, dtype: int64

# %%
#Saving a copy of the column
age_column = df['age'].values

#Removing the 'age' column
df = df.drop(['age'], axis = 1)

df
# Out:
#      sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0      1   3       145   233    1        0      150      0      2.3      0
# 1      1   2       130   250    0        1      187      0      3.5      0
# 2      0   1       130   204    0        0      172      0      1.4      2
# 3      1   1       120   236    0        1      178      0      0.8      2
# 4      0   0       120   354    0        1      163      1      0.6      2
# ..   ...  ..       ...   ...  ...      ...      ...    ...      ...    ...
# 298    0   0       140   241    0        1      123      1      0.2      1
# 299    1   3       110   264    0        1      132      0      1.2      1
# 300    1   0       144   193    1        1      141      0      3.4      1
# 301    1   0       130   131    0        1      115      1      1.2      1
# 302    0   1       130   236    0        0      174      0      0.0      1
#
#      ca  thal  target
# 0     0     1       1
# ...

# %%
df['age']  = age_column

# %%
#Shuffle the rown in a dataset
df = df.sample(frac = 1)

df
# Out:
#      sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 134    0   1       126   306    0        1      163      0      0.0      2
# 236    1   0       125   300    0        0      171      0      0.0      2
# 49     0   0       138   234    0        0      160      0      0.0      2
# 269    1   0       130   283    1        0      103      1      1.6      0
# 9      1   2       150   168    0        1      174      0      1.6      2
# ..   ...  ..       ...   ...  ...      ...      ...    ...      ...    ...
# 122    0   2       112   268    0        0      172      1      0.0      2
# 218    1   0       135   254    0        0      127      0      2.8      1
# 25     0   1       160   302    0        1      162      0      0.4      2
# 274    1   0       110   275    0        0      118      1      1.0      1
# 95     1   0       142   226    0        0      111      1      0.0      2
#
#      ca  thal  target  age
# 134   0     2       1   41
# ...

# %%
#Creating a new binary column that will show if the cholesterol is in the normal range or not
df['normal_cholesterol'] = df['chol']
