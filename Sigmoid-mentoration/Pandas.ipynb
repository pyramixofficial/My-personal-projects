# %%
import numpy as np
import pandas as pd

# %%
list_data = [np.random.random() for _ in range(200)]
series = pd.Series(list_data)

for element in series:
	print(element)
# Out:
# 0.7624497430368241
# 0.48123051722692844
# 0.6662852722052932
# 0.3793404760385162
# 0.40440246982768113
# 0.6408075689745201
# 0.5517860700304948
# 0.951067647215444
# 0.8941872208097348
# 0.5347449631614261
# 0.3327248420156744
# 0.4873047468475912
# 0.17779794953384465
# 0.4800585534536691
# 0.5059391964041281
# 0.030057377778955452
# 0.8374547528646382
# 0.08130456301568678
# 0.9499117238128777
# 0.5524402099567147
# 0.770839396782777
# 0.28742580806982965
# 0.8474908145765365
# 0.6127614146006131
# 0.06301040046343542
# 0.3843717574768153
# 0.3074289264303519
# 0.8981073024564971
# 0.8548011712837702
# 0.22226639454139197
# 0.45303118431668044
# 0.3042900807321979
# 0.5523991266020376
# 0.4221303358523919
# 0.5213844671886381
# 0.0703781919552755
# 0.10883698867182001
# 0.8018342634803017
# 0.9452468932842583
# 0.49396600170729543
# 0.08907790561711126
# 0.9815111326867779
# 0.039119163570918825
# 0.48963961903313924
# 0.9314437367036977
# 0.6848841213378052
# 0.27729155908139747
# 0.8808722496109493
# 0.5761540057290099
# 0.3392399225697976
# 0.8453890465829871
# 0.6292230627119999
# 0.11521841876674799
# 0.04647540665676353
# 0.6773985015498939
# 0.9157634862975949
# 0.1731935041677256
# 0.7399601953965977
# 0.7013841237538693
# 0.9107384202530919
# 0.18510093228980606
# 0.2834050496412207
# 0.1485912479638144
# 0.5782749522430745
# 0.38017612740883977
# 0.753017768478202
# 0.34610027570978896
# 0.6514724938163773
# 0.45857591400510944
# 0.4374745303155926
# 0.6014835722217725
# 0.1073214545827399
# 0.18244113167817333
# 0.2524055693335432
# 0.01820156138399509
# 0.5029165553101613
# 0.5030182924663636
# 0.6103507925774334
# 0.8534766716540961
# 0.9526532448089144
# 0.04708951312027865
# 0.392669341522102
# 0.9557719620032622
# 0.6249549536010284
# 0.08504997372241141
# 0.41039700923303124
# 0.3444886415169589
# 0.3885271407429932
# 0.4856128143669428
# 0.7512516526824227
# 0.1459951439937004
# 0.5793418823530618
# 0.1203463358387249
# 0.7638939521388121
# 0.6666414727052109
# 0.17799251555565776
# 0.08573065085330256
# 0.12043134785658205
# 0.7760889792560703
# 0.7296924634326972
# 0.8905212764367456
# 0.9959598919517583
# 0.09354806803949445
# 0.8064610825758863
# 0.5769950015031754
# 0.23724678749702943
# 0.32846056101568677
# 0.22957126797315408
# 0.4191842064693577
# 0.4334517806364625
# 0.4625996255228568
# 0.4051423387883373
# 0.40395463513603824
# 0.8579595737271718
# 0.16931821777355305
# 0.883162678243582
# 0.6047293376689561
# 0.018407914254280233
# 0.36783680982625544
# 0.46340861427888935
# 0.45252916681724376
# 0.14207583317840577
# 0.5173971187307084
# 0.09219410542048234
# 0.2988245571518847
# 0.9765509969753376
# 0.12005843641122549
# 0.9119002845924178
# 0.6076138464390837
# 0.760928729367391
# 0.05025489741942668
# 0.19033867291369577
# 0.09744094404035597
# 0.6232974475852663
# 0.6373796980865316
# 0.5444462967028261
# 0.6635560909455611
# 0.6323468334072543
# 0.8025206856244116
# 0.7441647818688018
# 0.32098618190405603
# 0.7700037682548306
# 0.9821645356631203
# 0.7681379092342594
# 0.8557945357806904
# 0.5598163179862027
# 0.8510602068790805
# 0.05636499089896452
# 0.6723757346722888
# 0.3711632115525687
# 0.8955899813401701
# 0.7794760154939658
# 0.6281072067453733
# 0.6361080677235675
# 0.5305783310964186
# 0.39565114986790106
# 0.9791462701410073
# 0.927637058671575
# 0.3839724671591407
# 0.7612365702374574
# 0.76018771989986
# 0.6589295307245694
# 0.055885645616018276
# 0.12069188160775124
# 0.5241668547052043
# 0.14008766533774808
# 0.18222117212605926
# 0.44303319255700735
# 0.5006374074455636
# 0.49549294380743747
# 0.3304421346478146
# 0.6097004610223516
# 0.10147879578148145
# 0.7568040757883889
# 0.6379360491403786
# 0.981347751779203
# 0.5586147744620269
# 0.29775395889688616
# 0.3489434786946053
# 0.7870497518822563
# 0.43727496270870037
# 0.11055870499874187
# 0.3725184149856877
# 0.2459308884410505
# 0.1256732171719085
# 0.5386878101581731
# 0.10956622346659473
# 0.19461798620970105
# 0.39478398856358776
# 0.4355784471113937
# 0.18516643422260193
# 0.6329037738919794
# 0.9238745958389553
# 0.427540292683674
# 0.49063353620252026
# 0.435376369918423
# 0.7140190867207592
# 0.9260742976900076
# 0.6683176613585435
# 0.601699382805873

# %%
#Computing the minimal value of a series
min_value = series.min()
print('\n', 'Minim value: ', min_value)
# Out:
#  Minim value:  0.01820156138399509

# %%
#Computing the maximal value of a series
max_value = series.max()
print('\n', 'Maximum value: ', max_value)
# Out:
#  Maximum value:  0.9959598919517583

# %%
#Computing the mean value of a series
mean = series.mean()
print('\n', 'Mean value: ',mean)
# Out:
#  Mean value:  0.5001350558825841

# %%
#Computing the median value of a series
median = series.median()
print('\n', 'Median value: ', median)
# Out:
#  Median value:  0.49806517562650054

# %%
#Computing the mode value of a series
mode = series.mode()
print('\n', 'Mode value: ', mode)
# Out:
#  Mode value:  0      0.018202
# 1      0.018408
# 2      0.030057
# 3      0.039119
# 4      0.046475
#          ...
# 195    0.979146
# 196    0.981348
# 197    0.981511
# 198    0.982165
# 199    0.995960
# Length: 200, dtype: float64

# %%
#Finding the index of the minimal value of series
min_index = series.argmin()
print('\n', 'Index of minimal value: ', min_index)
# Out:
#  Index of minimal value:  74

# %%
#Finding the index of the maximal value of series
min_index = series.argmax()
print('\n', 'Index of maximal value: ', max_index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14972/1507366428.py in <module>
#       1 #Finding the index of the maximal value of series
#       2 min_index = series.argmax()
# ----> 3 print('\n', 'Index of maximal value: ', max_index)
#
# NameError: name 'max_index' is not defined
